# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
name = Image.open("Thor.jpg")

# %%
arr = np.array(name)

# %%
arr.shape
# Out:
# (246, 220, 3)

# %%
cut = arr[100:246, 50:100]

# %%
plt.imshow(cut)
